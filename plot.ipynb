# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##### plot the limit of parameters in different mass #####
##### note that mass=10 GeV has no background event left #####

mass_large = [100, 80, 65, 50, 40, 30]
f_a_300_large = [56316.505642711876, 56888.88464056418, 82765.98443086533, 70245.8066962686, 65082.254560289985, 54795.06075820363]
g_azz_300_large = [0.00012622232006186134, 0.0001249523530811397, 8.58855246981043e-05, 0.00010119322895028198, 0.00010922178477107027, 0.000129727021042417]
g_azy_300_large = [5.912181744263196e-05, 5.852697212561038e-05, 4.0228291713204165e-05, 4.739833339820164e-05, 5.1158863320123574e-05, 6.076339946601636e-05]
error_f_a_300_large = [54187.8486542729, 54738.5928127489, 80826.73522553493, 69184.47977182003, 64155.90798326927, 54162.58490606154]
error_g_azz_300_large = [0.00013118070151396346, 0.00012986084652041725, 8.79461477710942e-05, 0.00010274558721037557, 0.00011079883713677226, 0.00013124188980877965]
error_g_azy_300_large = [6.144429513816506e-05, 6.082608255943142e-05, 4.119347585084065e-05, 4.812544918450826e-05, 5.189754568641828e-05, 6.147295538774671e-05]

f_a_3k_large = [103041.72817005747, 104089.00410512926, 152710.31825556717, 130853.62612624999, 121412.37319806058, 102783.248786407]
g_azz_3k_large = [6.89856442262738e-05, 6.82915554924568e-05, 4.654826262691557e-05, 5.4323293979324704e-05, 5.854757478798337e-05, 6.91591293710895e-05]
g_azy_3k_large = [3.2312483735913134e-05, 3.1987376517240526e-05, 2.1802941698040655e-05, 2.544472219977281e-05, 2.7423351326671455e-05, 3.239374319189347e-05]
g_aww_3k_large = []
error_f_a_3k_large = [82236.42195568362, 83072.24087322409, 131274.8091239011, 118309.18091086973, 110398.49662527812, 95149.38495579257]
error_g_azz_3k_large = [8.643858561636649e-05, 8.556889672505735e-05, 5.414900274805107e-05, 6.008324920578426e-05, 6.438855797219596e-05, 7.470778716333941e-05]
error_g_azy_3k_large = [4.048734230447936e-05, 4.007998496990759e-05, 2.5363085178610697e-05, 2.814265249730472e-05, 3.0159234658028808e-05, 3.4992702970831624e-05]

mass_small = [25, 20, 10, 5, 1]
f_a_300_small = [91661.95189008358, 106943.49482600614, 127795.27360626447, 127689.47827444515, 13730.590232956829]
g_azz_300_small = [7.755017052794203e-05, 6.646874605664565e-05, 5.5623340358430505e-05, 5.566942629933686e-05, 0.000517705348378839]
g_azy_300_small = [3.632405918660749e-05, 3.11335829358524e-05, 2.605365653720195e-05, 2.607524293003328e-05, 0.00024249024325433984]
error_f_a_300_small = [91661.95189008358, 106943.49482600614, 127795.27360626447, 127689.47827444515, 3916.7894361994877]
error_g_azz_300_small = [7.755017052794203e-05, 6.646874605664565e-05, 5.5623340358430505e-05, 5.566942629933686e-05, 0.001814853750958176]
error_g_azy_300_small = [3.632405918660749e-05, 3.11335829358524e-05, 2.605365653720195e-05, 2.607524293003328e-05, 0.0008500671838121722]

f_a_3k_small = [289860.5427494401, 338185.02458861185, 404124.1388001958, 298067.9584354117, 24440.9440477403]
g_azz_3k_small = [2.4523517180275926e-05, 2.101926307543356e-05, 1.75896446599407e-05, 2.3848252718315305e-05, 0.00029083982951375444]
g_azy_3k_small = [1.1486676089244283e-05, 9.845303379904552e-06, 8.238889603329359e-06, 1.1170386052537883e-05, 0.00013622772341002098]
error_f_a_3k_small = [289860.5427494401, 338185.02458861185, 404124.1388001958, 292051.8188227955, 3923.4329286528045]
error_g_azz_3k_small = [2.4523517180275926e-05, 2.101926307543356e-05, 1.75896446599407e-05, 2.4339516283968328e-05, 0.0018117806852482176]
error_g_azy_3k_small = [1.1486676089244283e-05, 9.845303379904552e-06, 8.238889603329359e-06, 1.1400491115022237e-05, 0.0008486277772967134]

##### data of gaWW is offered by Mark #####

w_mass_large= [100, 80, 65, 50, 40, 30]
g_aww_300_large = [6.212741782673705e-05, 6.073547582946208e-05, 5.947384211533281e-05, 5.2399724164063876e-05, 5.204141628433202e-05, 5.35007771707917e-05]
error_g_aww_300_large = [6.849307911139924e-05, 6.731830904567483e-05, 6.5849952049451e-05, 5.556664911369183e-05, 5.4533464773244286e-05, 5.5635948980260644e-05]
g_aww_3k_large = [3.435170842155201e-05, 3.360002350129941e-05, 3.289868346925823e-05, 2.8806993177223292e-05, 2.8523767180033515e-05, 2.924729212328804e-05]
error_g_aww_3k_large = [5.263369954949365e-05, 5.220997419136277e-05, 5.0979984658739006e-05, 3.915313593279911e-05, 3.703167606547523e-05, 3.674635971777937e-05]

w_mass_small= [25, 20, 10, 5, 1]
g_aww_300_small = [2.935511998160502e-05, 1.9003032617690298e-05, 1.901194208035067e-05, 2.604369871201064e-05, 0.00040871535034202615]
error_g_aww_300_small = [2.935511998160502e-05, 2.588590129947998e-05, 2.1125025447006432e-05, 2.6336157197472704e-05, 0.0025887227953401413]
g_aww_3k_small = [9.282904012939194e-06, 9.429365429050203e-06, 9.805005409199312e-06, 1.3869327180069703e-05, 0.00022976794631030678]
error_g_aww_3k_small = [9.282904012939194e-06, 9.535252767202237e-06, 1.0077420254082522e-05, 1.4937493122193459e-05, 0.0025883108051699996]

plt.plot(mass_large, f_a_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_f_a_300_large, color='blue', linestyle='dashed')
plt.plot(mass_large, f_a_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_f_a_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, f_a_300_small, color='blue')
plt.plot(mass_small, error_f_a_300_small, color='blue', linestyle='dashed')
plt.plot(mass_small, f_a_3k_small, color='orange')
plt.plot(mass_small, error_f_a_3k_small, color='orange', linestyle='dashed')
plt.xlabel("ALP mass (GeV)")
plt.ylabel("upper limit of $f_a ($GeV$)$")
plt.yscale("log")
plt.legend(loc='best')
plt.show()

plt.plot(mass_large, g_azz_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_g_azz_300_large, color='blue', linestyle='dashed')
plt.plot(mass_large, g_azz_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_g_azz_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, g_azz_300_small, color='blue')
plt.plot(mass_small, error_g_azz_300_small, color='blue', linestyle='dashed')
plt.plot(mass_small, g_azz_3k_small, color='orange')
plt.plot(mass_small, error_g_azz_3k_small, color='orange', linestyle='dashed')
plt.xlabel("ALP mass (GeV)")
plt.ylabel("lower limit of $g_{aZZ}$ ($GeV^{-1}$)")
plt.yscale("log")
plt.legend(loc='best')
plt.show()

plt.plot(mass_large, g_azy_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_g_azy_300_large, color='blue', linestyle='dashed')
plt.plot(mass_large, g_azy_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_g_azy_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, g_azy_300_small, color='blue')
plt.plot(mass_small, error_g_azy_300_small, color='blue', linestyle='dashed')
plt.plot(mass_small, g_azy_3k_small, color='orange')
plt.plot(mass_small, error_g_azy_3k_small, color='orange', linestyle='dashed')
plt.xlabel("ALP mass (GeV)")
plt.ylabel("lower limit of $g_{aZ\gamma}$ ($GeV^{-1}$)")
plt.yscale("log")
plt.legend(loc='best')
plt.show()

plt.plot(w_mass_large, g_aww_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(w_mass_large, error_g_aww_300_large, color='blue', linestyle='dashed')
plt.plot(w_mass_large, g_aww_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(w_mass_large, error_g_aww_3k_large, color='orange', linestyle='dashed')
plt.plot(w_mass_small, g_aww_300_small, color='blue')
plt.plot(w_mass_small, error_g_aww_300_small, color='blue', linestyle='dashed')
plt.plot(w_mass_small, g_aww_3k_small, color='orange')
plt.plot(w_mass_small, error_g_aww_3k_small, color='orange', linestyle='dashed')
plt.xlabel("ALP mass (GeV)")
plt.ylabel("lower limit of $g_{aWW}$ ($GeV^{-1}$)")
plt.yscale("log")
plt.legend(loc='best')
plt.show()

# %%
##### import current limit data #####

gazz = pd.read_csv("/data/Chen-Wang/gazz_import.csv")
gazz_gi_mass = gazz.gi_mass.to_numpy()
gazz_gi_gazz = gazz.gi_gazz.to_numpy()
gazz_photons_mass = gazz.photons_mass.to_numpy()
gazz_photons_gazz = gazz.photons_gazz.to_numpy()
gazz_NonresonantggF_mass = gazz.NonresonantggF_mass.to_numpy()
gazz_NonresonantggF_gazz = gazz.NonresonantggF_gazz.to_numpy()
gazz_LHCtriboson_mass = gazz.LHCtriboson_mass.to_numpy()
gazz_LHCtriboson_gazz = gazz.LHCtriboson_gazz.to_numpy()

gazy = pd.read_csv("/data/Chen-Wang/gazy_import.csv")
gazy_LEPZwidth_mass = gazy.LEPZwidth_mass.to_numpy()
gazy_LEPZwidth_gazy = gazy.LEPZwidth_gazy.to_numpy()
gazy_LEPZahad_mass = gazy.LEPZahad_mass.to_numpy()
gazy_LEPZahad_gazy = gazy.LEPZahad_gazy.to_numpy()
gazy_LHCtriboson_mass = gazy.LHCtriboson_mass.to_numpy()
gazy_LHCtriboson_gazy = gazy.LHCtriboson_gazy.to_numpy()
gazy_photons_mass = gazy.photons_mass.to_numpy()
gazy_photons_gazy = gazy.photons_gazy.to_numpy()
gazy_NonresonantggF_mass = gazy.NonresonantggF_mass.to_numpy()
gazy_NonresonantggF_gazy = gazy.NonresonantggF_gazy.to_numpy()
gazy_gi_mass = gazy.gi_mass.to_numpy()
gazy_gi_gazy = gazy.gi_gazy.to_numpy()

gaww = pd.read_csv("/data/Chen-Wang/gaww_import.csv")
gaww_photons_mass = gaww.photons_mass.to_numpy()
gaww_photons_gaww = gaww.photons_gaww.to_numpy()
gaww_LHCtriboson_mass = gaww.LHCtriboson_mass.to_numpy()
gaww_LHCtriboson_gaww = gaww.LHCtriboson_gaww.to_numpy()
gaww_NonresonantggF_mass = gaww.NonresonantggF_mass.to_numpy()
gaww_NonresonantggF_gaww = gaww.NonresonantggF_gaww.to_numpy()

# %%
##### plot our gazz result with current limit #####

y_upperlimit = 1
y_lowerlimit = 5e-6
x_upperlimit = 2000
x_lowerlimit = 1

plt.figure(figsize=(10,8))
##### our result #####
plt.plot(mass_large, g_azz_300_large, label='Our work, Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_g_azz_300_large, color='blue', linestyle='dashed')
plt.plot(mass_small, g_azz_300_small, color='blue')
plt.plot(mass_small, error_g_azz_300_small, color='blue', linestyle='dashed')
plt.plot(mass_large, g_azz_3k_large, label='Our work, Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_g_azz_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, g_azz_3k_small, color='orange')
plt.plot(mass_small, error_g_azz_3k_small, color='orange', linestyle='dashed')
#### current limit #####
plt.plot(gazz_photons_mass, gazz_photons_gazz)
plt.fill_between(gazz_photons_mass, gazz_photons_gazz, y_upperlimit, alpha=0.2, label="photons (various)")
plt.plot(gazz_NonresonantggF_mass, gazz_NonresonantggF_gazz)
plt.fill_between(gazz_NonresonantggF_mass, gazz_NonresonantggF_gazz, y_upperlimit, alpha=0.2, label="Nonresonant ZZ production (CMS)")
plt.plot(gazz_LHCtriboson_mass, gazz_LHCtriboson_gazz)
plt.fill_between(gazz_LHCtriboson_mass, gazz_LHCtriboson_gazz, y_upperlimit, alpha=0.2, label="triboson (LHC)")

plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("ALP mass (GeV)")
plt.ylabel("$\\rmg_{aZZ} (GeV^{-1})$")
plt.legend(loc='best')
plt.show()

# %%
##### plot our gazy result with current limit #####

y_upperlimit = 1
y_lowerlimit = 5e-6
x_upperlimit = 2000
x_lowerlimit = 1

plt.figure(figsize=(10,8))
plt.plot(mass_large, g_azy_300_large, label='Our work, Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_g_azy_300_large, color='blue', linestyle='dashed')
plt.plot(mass_small, g_azy_300_small, color='blue')
plt.plot(mass_small, error_g_azy_300_small, color='blue', linestyle='dashed')
plt.plot(mass_large, g_azy_3k_large, label='Our work, Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_g_azy_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, g_azy_3k_small, color='orange')
plt.plot(mass_small, error_g_azy_3k_small, color='orange', linestyle='dashed')

#plt.plot(gazy_gi_mass, gazy_gi_gazy, label="g.i.")
plt.plot(gazy_LEPZwidth_mass, gazy_LEPZwidth_gazy)
plt.fill_between(gazy_LEPZwidth_mass, gazy_LEPZwidth_gazy, y_upperlimit, alpha=0.2, label="Z width (LEP)")
plt.plot(gazy_LEPZahad_mass, gazy_LEPZahad_gazy)
plt.fill_between(gazy_LEPZahad_mass, gazy_LEPZahad_gazy, y_upperlimit, alpha=0.2, label="$\\rmZ \\rightarrow \gamma + had \;(LEP)$")
plt.plot(gazy_LHCtriboson_mass, gazy_LHCtriboson_gazy)
plt.fill_between(gazy_LHCtriboson_mass, gazy_LHCtriboson_gazy, y_upperlimit, alpha=0.2, label="triboson (LHC)")
plt.plot(gazy_photons_mass, gazy_photons_gazy)
plt.fill_between(gazy_photons_mass, gazy_photons_gazy, y_upperlimit, alpha=0.2, label="photons (various)")
plt.plot(gazy_NonresonantggF_mass, gazy_NonresonantggF_gazy)
plt.fill_between(gazy_NonresonantggF_mass, gazy_NonresonantggF_gazy, y_upperlimit, alpha=0.2, label="Nonresonant ggF (LHC)")

plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("ALP mass (GeV)")
plt.ylabel("$\\rmg_{aZ\gamma} (GeV^{-1})$")
plt.legend(loc='best')
plt.show()

# %%
##### plot our gaww result with current limit #####

y_upperlimit = 1
y_lowerlimit = 5e-6
x_upperlimit = 2000
x_lowerlimit = 1

plt.figure(figsize=(10,8))
plt.plot(w_mass_large, g_aww_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(w_mass_large, error_g_aww_300_large, color='blue', linestyle='dashed')
plt.plot(w_mass_large, g_aww_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(w_mass_large, error_g_aww_3k_large, color='orange', linestyle='dashed')
plt.plot(w_mass_small, g_aww_300_small, color='blue')
plt.plot(w_mass_small, error_g_aww_300_small, color='blue', linestyle='dashed')
plt.plot(w_mass_small, g_aww_3k_small, color='orange')
plt.plot(w_mass_small, error_g_aww_3k_small, color='orange', linestyle='dashed')

plt.plot(gaww_LHCtriboson_mass, gaww_LHCtriboson_gaww)
plt.fill_between(gaww_LHCtriboson_mass, gaww_LHCtriboson_gaww, y_upperlimit, alpha=0.2, label="triboson (LHC)")
plt.plot(gaww_photons_mass, gaww_photons_gaww)
plt.fill_between(gaww_photons_mass, gaww_photons_gaww, y_upperlimit, alpha=0.2, label="photons (various)")
plt.plot(gaww_NonresonantggF_mass, gaww_NonresonantggF_gaww)
plt.fill_between(gaww_NonresonantggF_mass, gaww_NonresonantggF_gaww, y_upperlimit, alpha=0.2, label="Nonresonant ggF (LHC)")

plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("ALP mass (GeV)")
plt.ylabel("$\\rmg_{aWW} (GeV^{-1})$")
plt.legend(loc='best')
plt.show()

# %%
plt.figure(1, figsize=(20,16))
plt.subplots_adjust(wspace=0.25, hspace=0.25)

#########################################
############### plot gaZZ ###############
#########################################
ax1 = plt.subplot(221)
y_upperlimit = 1
y_lowerlimit = 5e-6
x_upperlimit = 100
x_lowerlimit = 1
##### our result #####
plt.plot(mass_large, g_azz_300_large, label='Our work, Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_g_azz_300_large, color='blue', linestyle='dashed')
plt.plot(mass_small, g_azz_300_small, color='blue')
plt.plot(mass_small, error_g_azz_300_small, color='blue', linestyle='dashed')
plt.plot(mass_large, g_azz_3k_large, label='Our work, Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_g_azz_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, g_azz_3k_small, color='orange')
plt.plot(mass_small, error_g_azz_3k_small, color='orange', linestyle='dashed')
##### current limit #####
plt.plot(gazz_photons_mass, gazz_photons_gazz)
plt.fill_between(gazz_photons_mass, gazz_photons_gazz, y_upperlimit, alpha=0.2, label="photons (various)")
plt.plot(gazz_NonresonantggF_mass, gazz_NonresonantggF_gazz)
plt.fill_between(gazz_NonresonantggF_mass, gazz_NonresonantggF_gazz, y_upperlimit, alpha=0.2, label="Nonresonant ZZ production (CMS)")
plt.plot(gazz_LHCtriboson_mass, gazz_LHCtriboson_gazz)
plt.fill_between(gazz_LHCtriboson_mass, gazz_LHCtriboson_gazz, y_upperlimit, alpha=0.2, label="triboson (LHC)")
##### adjustment #####
plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("$M_a\; \\rm{(GeV)}$", fontsize=18)
plt.ylabel("$g_{aZZ}\; \\rm{(GeV^{-1})}$", fontsize=18)
plt.legend(loc='upper left')

#########################################
############### plot gaZy ###############
#########################################
ax2 = plt.subplot(222)
y_upperlimit = 1
y_lowerlimit = 5e-6
x_upperlimit = 100
x_lowerlimit = 1
##### our result #####
plt.plot(mass_large, g_azy_300_large, label='Our work, Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, error_g_azy_300_large, color='blue', linestyle='dashed')
plt.plot(mass_small, g_azy_300_small, color='blue')
plt.plot(mass_small, error_g_azy_300_small, color='blue', linestyle='dashed')
plt.plot(mass_large, g_azy_3k_large, label='Our work, Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_large, error_g_azy_3k_large, color='orange', linestyle='dashed')
plt.plot(mass_small, g_azy_3k_small, color='orange')
plt.plot(mass_small, error_g_azy_3k_small, color='orange', linestyle='dashed')
##### current limit #####
plt.plot(gazy_LEPZwidth_mass, gazy_LEPZwidth_gazy)
plt.fill_between(gazy_LEPZwidth_mass, gazy_LEPZwidth_gazy, y_upperlimit, alpha=0.2, label="Z width (LEP)")
plt.plot(gazy_LEPZahad_mass, gazy_LEPZahad_gazy)
plt.fill_between(gazy_LEPZahad_mass, gazy_LEPZahad_gazy, y_upperlimit, alpha=0.2, label="$\\rmZ \\rightarrow \gamma + had \;(LEP)$")
plt.plot(gazy_LHCtriboson_mass, gazy_LHCtriboson_gazy)
plt.fill_between(gazy_LHCtriboson_mass, gazy_LHCtriboson_gazy, y_upperlimit, alpha=0.2, label="triboson (LHC)")
plt.plot(gazy_photons_mass, gazy_photons_gazy)
plt.fill_between(gazy_photons_mass, gazy_photons_gazy, y_upperlimit, alpha=0.2, label="photons (various)")
plt.plot(gazy_NonresonantggF_mass, gazy_NonresonantggF_gazy)
plt.fill_between(gazy_NonresonantggF_mass, gazy_NonresonantggF_gazy, y_upperlimit, alpha=0.2, label="Nonresonant ggF (LHC)")
##### adjustment #####
plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("$M_a\; \\rm{(GeV)}$", fontsize=18)
plt.ylabel("$g_{aZ\gamma}\; \\rm{(GeV^{-1})}$", fontsize=18)
plt.legend(loc='upper left')

#########################################
############### plot gaWW ###############
#########################################
ax3 = plt.subplot(223)
y_upperlimit = 1
y_lowerlimit = 5e-6
x_upperlimit = 100
x_lowerlimit = 1
##### our result #####
plt.plot(w_mass_large, g_aww_300_large, label='Our work, Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(w_mass_large, error_g_aww_300_large, color='blue', linestyle='dashed')
plt.plot(w_mass_large, g_aww_3k_large, label='Our work, Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(w_mass_large, error_g_aww_3k_large, color='orange', linestyle='dashed')
plt.plot(w_mass_small, g_aww_300_small, color='blue')
plt.plot(w_mass_small, error_g_aww_300_small, color='blue', linestyle='dashed')
plt.plot(w_mass_small, g_aww_3k_small, color='orange')
plt.plot(w_mass_small, error_g_aww_3k_small, color='orange', linestyle='dashed')
##### current limit #####
plt.plot(gaww_LHCtriboson_mass, gaww_LHCtriboson_gaww)
plt.fill_between(gaww_LHCtriboson_mass, gaww_LHCtriboson_gaww, y_upperlimit, alpha=0.2, label="triboson (LHC)")
plt.plot(gaww_photons_mass, gaww_photons_gaww)
plt.fill_between(gaww_photons_mass, gaww_photons_gaww, y_upperlimit, alpha=0.2, label="photons (various)")
plt.plot(gaww_NonresonantggF_mass, gaww_NonresonantggF_gaww)
plt.fill_between(gaww_NonresonantggF_mass, gaww_NonresonantggF_gaww, y_upperlimit, alpha=0.2, label="Nonresonant ggF (LHC)")
##### adjustment #####
plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("$M_a\; \\rm{(GeV)}$", fontsize=18)
plt.ylabel("$g_{aWW}\; \\rm{(GeV^{-1})}$", fontsize=18)
plt.legend(loc='upper left')

plt.show()

# %%
##### plot cross section to mass plot for both events #####

mass_z = [100, 80, 65, 50, 40, 30, 25, 20, 10, 5, 1]    ### unit GeV
Xsection_z = [0.50649175, 0.61386505, 0.71604242, 0.84357505, 0.9481855743, 1.070586486, 1.14001539, 1.22189221, 1.42137789, 1.52379466, 1.57380488]    ### unit pb
Xsection_llaa = [0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201, 0.09909201]    ### unit pb
Xsection_llj = [549.8359, 549.8359, 549.8359, 549.8359, 549.8359, 549.8359, 549.8359, 549.8359, 549.8359, 549.8359, 549.8359]    ### unit pb

    # pp > wax data is offered by Mark

mass_w = [100, 90, 80, 70, 60, 50, 40, 30, 25, 20, 10, 5, 1]    ### unit GeV
Xsection_w = [4.584, 5.059, 5.583, 6.252, 6.998, 7.858, 8.969, 10.220, 10.890, 11.850, 14.060, 15.250, 15.990]   ### unit pb
Xsection_lvaa = [0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518, 0.0943704518]   ### unit pb
Xsection_lvj = [5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01, 5887.01]   ### unit pb

plt.figure(figsize=(9,7))
plt.plot(mass_z, Xsection_z, label='signal')
plt.plot(mass_z, Xsection_llaa, label='$ll\gamma \gamma$BG', linestyle='dashed')
plt.plot(mass_z, Xsection_llj, label='$llj$BG', linestyle='dashed')
plt.xlabel("$M_a\; \\rm{(GeV)}$", fontsize=18)
plt.ylabel("$\sigma \; \\rm{(pb)}$", fontsize=18)
plt.xscale("log")
plt.yscale("log")
plt.xlim(1,100)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.legend(loc="best", fontsize=18)
plt.show()

plt.figure(figsize=(9,7))
plt.plot(mass_w, Xsection_w, label='signal')
plt.plot(mass_w, Xsection_lvaa, label='$l\\nu_l \gamma \gamma $BG', linestyle='dashed')
plt.plot(mass_w, Xsection_lvj, label='$llj$BG', linestyle='dashed')
plt.xlabel("$M_a\; \\rm{(GeV)}$", fontsize=18)
plt.ylabel("$\sigma \; \\rm{(pb)}$", fontsize=18)
plt.xscale("log")
plt.yscale("log")
plt.xlim(1,100)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.legend(loc="best", fontsize=18)
plt.show()

# %%
##### import ga\gamma\gamma current limit data #####

gayy = pd.read_csv("/data/Chen-Wang/gayy_import.csv")

gayy_ATLAS_mass = gayy.ATLAS_mass.to_numpy()
gayy_ATLAS_gayy = gayy.ATLAS_gayy.to_numpy()
gayy_BD_mass = gayy.BD_mass.to_numpy()
gayy_BD_gayy = gayy.BD_gayy.to_numpy()
gayy_Belle_mass = gayy.Belle_mass.to_numpy()
gayy_Belle_gayy = gayy.Belle_gayy.to_numpy()
gayy_BES_mass = gayy.BES_mass.to_numpy()
gayy_BES_gayy = gayy.BES_gayy.to_numpy()
gayy_CMS_mass = gayy.CMS_mass.to_numpy()
gayy_CMS_gayy = gayy.CMS_gayy.to_numpy()
gayy_LEP_mass = gayy.LEP_mass.to_numpy()
gayy_LEP_gayy = gayy.LEP_gayy.to_numpy()
gayy_LHC_mass = gayy.LHC_mass.to_numpy()
gayy_LHC_gayy = gayy.LHC_gayy.to_numpy()
gayy_OPAL_mass = gayy.OPAL_mass.to_numpy()
gayy_OPAL_gayy = gayy.OPAL_gayy.to_numpy()
gayy_Prime_mass = gayy.Prime_mass.to_numpy()
gayy_Prime_gayy = gayy.Prime_gayy.to_numpy()
gayy_Sne_mass = gayy.Sne_mass.to_numpy()
gayy_Sne_gayy = gayy.Sne_gayy.to_numpy()

# %%
##### calculae g_a\gamma\gamma using g_aZZ and g_aWW #####

sin_W_square = 0.22290    ### sine square of Weinberg angle
cos_W_square = 1-sin_W_square    ### cosine square of Weinberg angle

g_ayy_300_large = (cos_W_square/sin_W_square)*(np.array(g_azz_300_large)-np.array(g_aww_300_large)*cos_W_square) + np.array(g_aww_300_large)*sin_W_square
g_ayy_3k_large = (cos_W_square/sin_W_square)*(np.array(g_azz_3k_large)-np.array(g_aww_3k_large)*cos_W_square) + np.array(g_aww_3k_large)*sin_W_square
g_ayy_300_small = (cos_W_square/sin_W_square)*(np.array(g_azz_300_small)-np.array(g_aww_300_small)*cos_W_square) + np.array(g_aww_300_small)*sin_W_square
g_ayy_3k_small = (cos_W_square/sin_W_square)*(np.array(g_azz_3k_small)-np.array(g_aww_3k_small)*cos_W_square) + np.array(g_aww_3k_small)*sin_W_square

plt.plot(mass_large, g_ayy_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, g_ayy_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_small, g_ayy_300_small, color='blue')
plt.plot(mass_small, g_ayy_3k_small, color='orange')
plt.xlabel("ALP mass (GeV)")
plt.ylabel("lower limit of $g_{a\gamma \gamma }$ ($GeV^{-1}$)")
plt.yscale("log")
plt.legend(loc='best')
plt.show()

# %%
##### plot g_a\gamma\gamma limit #####

y_upperlimit = 0.1
y_lowerlimit = 5e-6
x_upperlimit = 100
x_lowerlimit = 1

plt.figure(figsize=(10,8))
plt.plot(mass_large, g_ayy_300_large, label='Luminosity=300$(fb^{-1})$', color='blue')
plt.plot(mass_large, g_ayy_3k_large, label='Luminosity=3000$(fb^{-1})$', color='orange')
plt.plot(mass_small, g_ayy_300_small, color='blue')
plt.plot(mass_small, g_ayy_3k_small, color='orange')

plt.fill_between(gayy_ATLAS_mass, gayy_ATLAS_gayy, y_upperlimit, alpha=0.2, label="ATLAS")
plt.plot(gayy_ATLAS_mass, gayy_ATLAS_gayy)
#plt.fill_between(gayy_BD_mass, gayy_BD_gayy, y_upperlimit, alpha=0.2, label="Beam dump")
#plt.plot(gayy_BD_mass, gayy_BD_gayy)
plt.fill_between(gayy_Belle_mass, gayy_Belle_gayy, y_upperlimit, alpha=0.2, label="Belle II")
plt.plot(gayy_Belle_mass, gayy_Belle_gayy)
plt.fill_between(gayy_BES_mass, gayy_BES_gayy, y_upperlimit, alpha=0.2, label="BES III")
plt.plot(gayy_BES_mass, gayy_BES_gayy)
plt.fill_between(gayy_CMS_mass, gayy_CMS_gayy, y_upperlimit, alpha=0.2, label="CMS")
plt.plot(gayy_CMS_mass, gayy_CMS_gayy)
plt.fill_between(gayy_LEP_mass, gayy_LEP_gayy, y_upperlimit, alpha=0.2, label="LEP")
plt.plot(gayy_LEP_mass, gayy_LEP_gayy)
plt.fill_between(gayy_LHC_mass, gayy_LHC_gayy, y_upperlimit, alpha=0.2, label="LHC (pp)")
plt.plot(gayy_LHC_mass, gayy_LHC_gayy)
plt.fill_between(gayy_OPAL_mass, gayy_OPAL_gayy, y_upperlimit, alpha=0.2, label="OPAL")
plt.plot(gayy_OPAL_mass, gayy_OPAL_gayy)
plt.fill_between(gayy_Prime_mass, gayy_Prime_gayy, y_upperlimit, alpha=0.2, label="PrimEx")
plt.plot(gayy_Prime_mass, gayy_Prime_gayy)
#plt.fill_between(gayy_Sne_mass, gayy_Sne_gayy, y_upperlimit, alpha=0.2, label="SNe")
#plt.plot(gayy_Sne_mass, gayy_Sne_gayy)

plt.ylim(y_lowerlimit,y_upperlimit)
plt.xlim(x_lowerlimit,x_upperlimit)
plt.xscale("log")
plt.yscale("log")
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel("ALP mass (GeV)", fontsize=18)
plt.ylabel("$\\rmg_{a\gamma \gamma } (GeV^{-1})$", fontsize=18)
plt.legend(loc='best')
plt.show()
